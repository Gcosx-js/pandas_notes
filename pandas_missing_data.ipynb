# %% [markdown]
# # Missing data

# %%
import pandas as pd;import numpy as np

# %%
s = pd.Series(['Elmir','Salam',np.nan,4,np.nan,'ok'])
s.notnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
s[5]=None
s
# Out:
# 0    Elmir
# 1    Salam
# 2      NaN
# 3        4
# 4      NaN
# 5     None
# dtype: object

# %%
dt = pd.read_csv('data.csv',usecols=np.arange(0,8))
dt
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M       17.990         10.38          122.80     1001.0
# 1     842517         M       20.570         17.77          132.90     1326.0
# 2   84300903         M       19.690         21.25          130.00     1203.0
# 3   84348301         M       11.420         20.38           77.58      386.1
# 4   84358402         M       20.290         14.34          135.10     1297.0
# 5     843786         M       12.450         15.70           82.57      477.1
# 6     844359         M       18.250         19.98          119.60     1040.0
# 7   84458202         M       13.710         20.83           90.20      577.9
# 8     844981         M       13.000         21.82           87.50      519.8
# 9   84501001         M       12.460         24.04           83.97      475.9
# 10    845636         M       16.020         23.24          102.70      797.8
# ...

# %%
# Replace random datas with NaN (for test)
from random import randrange as rang

# %%
for i in range(15):#15 NaN
    r_i = rang(0,len(dt['id'])) #Random index
    r_c = dt.columns[rang(0,len(dt.columns))] #Random column
    dt.loc[r_i,r_c] = None

dt
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0     842302.0         M       17.990         10.38          122.80
# 1     842517.0         M       20.570         17.77             NaN
# 2   84300903.0         M       19.690         21.25          130.00
# 3   84348301.0         M       11.420         20.38           77.58
# 4          NaN         M          NaN           NaN          135.10
# 5     843786.0         M       12.450         15.70           82.57
# 6     844359.0         M          NaN         19.98          119.60
# 7   84458202.0         M       13.710           NaN           90.20
# 8     844981.0         M       13.000         21.82           87.50
# 9   84501001.0         M       12.460         24.04           83.97
# 10         NaN         M       16.020         23.24          102.70
# 11  84610002.0         M          NaN         17.89          103.60
# 12    846226.0         M       19.170         24.80          132.40
# ...

# %%
dt2 = dt
#dt2.dropna(thresh=7) we can also use 'axis=1','how='all'' methods with dropna

# %%
#Complete missing data

dt2.fillna('I am not here :D').head() #its temporary filling



# if we add inplace=True the real datas of dataset will change
dt2.fillna('Hello',inplace=True)
dt2.head()
# Out:
#            id diagnosis radius_mean texture_mean perimeter_mean area_mean  \
# 0    842302.0         M       17.99        10.38          122.8    1001.0
# 1    842517.0         M       20.57        17.77          Hello    1326.0
# 2  84300903.0         M       19.69        21.25          130.0    1203.0
# 3  84348301.0         M       11.42        20.38          77.58     386.1
# 4       Hello         M       Hello        Hello          135.1    1297.0
#
#    smoothness_mean compactness_mean
# 0          0.11840           0.2776
# 1          0.08474          0.07864
# 2          0.10960           0.1599
# 3          0.14250           0.2839
# 4          0.10030           0.1328

# %%
# Out:
#             id diagnosis radius_mean texture_mean perimeter_mean area_mean  \
# 0     842302.0         M       17.99        10.38          122.8    1001.0
# 1     842517.0         M       20.57        17.77          Hello    1326.0
# 2   84300903.0         M       19.69        21.25          130.0    1203.0
# 3   84348301.0         M       11.42        20.38          77.58     386.1
# 4        Hello         M       Hello        Hello          135.1    1297.0
# 5     843786.0         M       12.45         15.7          82.57     477.1
# 6     844359.0         M       Hello        19.98          119.6    1040.0
# 7   84458202.0         M       13.71        Hello           90.2     577.9
# 8     844981.0         M        13.0        21.82           87.5     519.8
# 9   84501001.0         M       12.46        24.04          83.97     475.9
# 10       Hello         M       16.02        23.24          102.7     797.8
# ...
